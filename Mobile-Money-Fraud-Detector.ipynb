# %% [markdown]
# <div style="background-color:#1f4e79; padding:35px; border-radius:15px; text-align:center; color:white;">
#
# # CAPSTONE PROJECT
#
# # Mobile Money Fraud Detector
# ### AI-Powered Fraud Detection and Transaction Analysis Using Machine Learning
#
# ---
#
# ## Project Overview
#
# Mobile money services have transformed financial transactions in Nigeria by providing fast, accessible, and convenient digital payment solutions through platforms such as **OPay, Moniepoint, PalmPay, Paga, and Kuda**. These platforms have improved financial inclusion by allowing millions of individuals and businesses to perform financial transactions digitally.
#
# However, the rapid growth of mobile money adoption has also increased the risk of fraudulent activities. Mobile money agents and financial service providers face challenges in identifying suspicious transaction patterns due to the large volume of daily transactions and the complexity of fraudulent behaviours.
#
# Fraudulent transactions often contain hidden patterns such as unusual transaction amounts, abnormal balance changes, suspicious transfer behaviours, and irregular account activities. Detecting these patterns manually is difficult and requires an intelligent data-driven approach.
#
# This project focuses on developing a **Mobile Money Fraud Detector** using the **PaySim Mobile Money Transactions Dataset**. The objective is to analyze transaction data, discover fraud patterns, and prepare a machine learning pipeline capable of classifying transactions as either **fraudulent** or **legitimate**.
#
# This notebook presents the first phase of the end-to-end machine learning workflow, focusing on understanding the dataset, performing data exploration, identifying data quality issues, analyzing transaction patterns, and preparing the data for future machine learning development.
#
# ---
#
# # Project Title
#
# ## Mobile Money Fraud Detector: Data Analysis and Machine Learning Pipeline for Fraud Detection
#
# ---
#
# ## Problem Statement
#
# The increasing use of mobile money services has created new opportunities for digital financial fraud. Mobile money agents and financial institutions process thousands of transactions daily, making it challenging to manually monitor every transaction for suspicious activities.
#
# Traditional fraud detection methods may fail to identify complex transaction patterns, especially when fraudulent activities appear similar to normal transactions.
#
# An intelligent fraud detection system can help by analyzing historical transaction data, identifying unusual behaviours, and learning patterns associated with fraudulent activities.
#
# This project aims to build a machine learning foundation that can support automatic fraud detection by transforming raw mobile money transaction records into meaningful insights and predictive features.
#
# ---
#
# ## Project Objectives
#
# The primary objectives of this project are to:
#
# 1. Explore and understand the structure of the **PaySim Mobile Money Transactions Dataset**.
#
# 2. Load and inspect transaction data to understand:
#    - Dataset size.
#    - Available features.
#    - Data types.
#    - Transaction characteristics.
#
# 3. Perform data quality assessment by identifying:
#    - Missing values.
#    - Duplicate records.
#    - Incorrect data formats.
#    - Inconsistent transaction information.
#
# 4. Conduct Exploratory Data Analysis (EDA) to understand:
#    - Transaction distribution.
#    - Fraud occurrence patterns.
#    - Relationship between transaction types and fraud cases.
#    - Transaction amount behaviour.
#    - Balance changes associated with fraudulent activities.
#
# 5. Analyze important transaction features including:
#    - Transaction type.
#    - Transaction amount.
#    - Sender balance before and after transactions.
#    - Receiver balance before and after transactions.
#    - Fraud indicators.
#
# 6. Visualize transaction patterns using:
#    - Distribution plots.
#    - Fraud class analysis.
#    - Correlation analysis.
#    - Feature comparisons.
#
# 7. Prepare the dataset for machine learning by:
#    - Cleaning transaction records.
#    - Encoding categorical variables.
#    - Selecting relevant features.
#    - Creating a foundation for model development.
#
# 8. Establish the groundwork for future machine learning stages including:
#    - Feature engineering.
#    - Model training.
#    - Class imbalance handling.
#    - Fraud prediction.
#
# ---
#
# ## Dataset
#
# **Dataset:** PaySim Mobile Money Transactions Dataset
#
# The PaySim dataset contains simulated mobile money transaction records designed to represent real-world financial transaction activities.
#
# Each transaction contains information about transaction behaviour, including:
#
# - Transaction type.
# - Transaction amount.
# - Sender account balance.
# - Receiver account balance.
# - Fraud classification status.
#
# The dataset provides a realistic environment for developing and testing fraud detection models.
#
# ---
#
# ## Target Variable
#
# The main prediction target is:
#
# **isFraud**
#
# This variable indicates whether a transaction is fraudulent or legitimate.
#
# - **0** → Legitimate Transaction
# - **1** → Fraudulent Transaction
#
# The objective of the project is to understand the patterns behind fraudulent transactions and prepare the dataset for building a machine learning classification model.
#
# ---
#
# ## Machine Learning Workflow
#
# This project follows a structured machine learning workflow:
#
# - Business Problem Understanding
# - Dataset Loading
# - Data Inspection
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - Fraud Pattern Analysis
# - Feature Understanding
# - Data Preprocessing Preparation
# - Feature Engineering
# - Machine Learning Model Development
# - Model Evaluation
# - Fraud Prediction System
#
# ---
#
# ## Expected Outcome
#
# At the end of this project phase, the dataset will be fully understood, cleaned, analyzed, and prepared for machine learning development.
#
# The insights gained from exploratory analysis will help identify important transaction behaviours associated with fraud and guide the creation of effective machine learning features.
#
# The complete project will eventually produce an AI-powered fraud detection system capable of analyzing mobile money transactions, identifying suspicious activities, and supporting safer digital financial services in Nigeria.
#
# </div>

# %% [markdown]
# ## *Import Required Libraries*
# This section imports all the Python libraries required for data manipulation, visualization, preprocessing, machine learning, model evaluation, and model saving.

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warning messages
import warnings
warnings.filterwarnings('ignore')

# Data Preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# Train-Test Split
from sklearn.model_selection import train_test_split

# Machine Learning Algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# Handle Class Imbalance
from imblearn.over_sampling import SMOTE

# Model Evaluation
from sklearn.metrics import (accuracy_score,precision_score, recall_score,f1_score,roc_auc_score, confusion_matrix, classification_report, roc_curve)

# Save Model
import joblib

# %% [markdown]
# ## Configure Visualization Settings
#
# We configure visualization settings to produce cleaner and more readable plots throughout the analysis.
# Code Cell

# %%
# Set plot style
plt.style.use("ggplot")

# Default figure size
plt.rcParams["figure.figsize"] = (10, 6)

# Display all columns
pd.set_option("display.max_columns", None)

# Display numbers with two decimal places
pd.options.display.float_format = "{:.2f}".format

# %%
# Load the dataset
df = pd.read_csv("paysim dataset.csv")

# Display confirmation
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# <div style="font-family: 'Segoe UI', Arial, sans-serif;">
#
# # <span style="color:#1F4E79;">📂 Dataset Loading</span>
#
# ## <span style="color:#2E86C1;">Overview</span>
#
# <p style="font-size:16px; line-height:1.8; text-align:justify;">
# In this section, we load the <strong>PaySim</strong> dataset into a <strong>Pandas DataFrame</strong>. After successfully loading the dataset, we perform a series of initial inspections to verify that the data has been imported correctly and to gain a basic understanding of its structure. These checks ensure the dataset is ready for subsequent data understanding, cleaning, and preprocessing tasks.
# </p>
#
# ### <span style="color:#2874A6;">📋 Initial checks include:</span>
#
# - 📥 Loading the dataset into a Pandas DataFrame
# - 👀 Viewing the first five rows of the dataset
# - 📄 Viewing the last five rows of the dataset
# - 📐 Checking the dataset dimensions (rows and columns)
# - 🏷️ Listing all column names
#
# > **Note:** These preliminary inspections help confirm that the dataset has been loaded correctly and provide a quick overview of its structure before proceeding to detailed data exploration and analysis.
#
# </div>

# %%
# Display the first five rows
df.head()

# Display the last five rows
df.tail()

# Display the number of rows and columns
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")

# Display all column names
df.columns

# Display five random transactions
df.sample(5, random_state=42)

# Display basic information
print("Dataset Shape:", df.shape)
print("\nNumber of Features:", df.shape[1] - 1)
print("Number of Records:", df.shape[0])
# Out:
# Number of Rows: 6362620
# Number of Columns: 11
# Dataset Shape: (6362620, 11)
#
# Number of Features: 10
# Number of Records: 6362620

# %% [markdown]
# <div style="font-family: 'Segoe UI', Arial, sans-serif;">
#
# # <span style="color:#1F4E79;">📊 Data Understanding</span>
#
# ## <span style="color:#2E86C1;">Overview</span>
#
# <p style="font-size:16px; line-height:1.8; text-align:justify;">
# Data understanding is a critical stage in the machine learning workflow. It involves examining the dataset to understand its structure, identify data quality issues, and gain meaningful insights into the variables. This step helps determine the appropriate data cleaning, preprocessing, and feature engineering techniques required before model development.
# </p>
#
# ### <span style="color:#2874A6;">🔍 In this section, we will:</span>
#
# - 📁 Examine the dataset structure
# - 🔢 Check data types
# - ❓ Identify missing values
# - 🔄 Detect duplicate records
# - 📈 Generate descriptive statistics
# - 🏷️ Explore unique values in categorical variables
# - 🎯 Analyze the target variable distribution
# - 💳 Examine transaction types
# - 💾 Check memory usage
#
# > **Note:** These analyses will provide valuable insights into the dataset and guide the subsequent **Data Cleaning** and **Data Preprocessing** stages.
#
# </div>

# %%
# Display dataset information
df.info()

# Display data types
df.dtypes

# Summary statistics
df.describe().T

# Include categorical variables
df.describe(include='all').T

# Count missing values
missing_values = df.isnull().sum()

missing_values

# Number of duplicate rows
duplicates = df.duplicated().sum()

print("Duplicate Records:", duplicates)

print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")

# Display columns names
df.columns.tolist()

# Number of unique values
df.nunique().sort_values()

# Unique transaction types
df['type'].unique()

# Count each transaction type
df['type'].value_counts()

# Fraud counts
df['isFraud'].value_counts()

df['isFlaggedFraud'].value_counts()

data_quality = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Missing %": (df.isnull().sum() / len(df)) * 100,
    "Unique Values": df.nunique()
})

data_quality
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB
# Duplicate Records: 0
# Rows    : 6362620
# Columns : 11
#                Data Type  Missing Values  Missing %  Unique Values
# step               int64               0       0.00            743
# type              object               0       0.00              5
# amount           float64               0       0.00        5316900
# nameOrig          object               0       0.00        6353307
# ...

# %% [markdown]
# # 🧹 Data Cleaning
#
# ---
#
# ## 📌 Overview
#
# Data cleaning is a crucial step in the machine learning workflow. The quality of a machine learning model depends heavily on the quality of the data used for training.
#
# Real-world datasets often contain issues such as missing values, duplicate records, inconsistent data types, or irrelevant features. These issues can negatively affect model performance and lead to inaccurate predictions.
#
# In this section, we will clean the PaySim dataset to ensure it is reliable and suitable for further analysis and machine learning.

# %%
# Dataset shape before cleaning
print("Dataset Shape Before Cleaning:", df.shape)

# Missing values in each column
df.isnull().sum()
# Out:
# Dataset Shape Before Cleaning: (6362620, 11)
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
# Remove rows with missing values
df.dropna(inplace=True)

print("Missing values removed successfully.")
# Out:
# Missing values removed successfully.

# %%
# Count duplicate rows
duplicates = df.duplicated().sum()

print(f"Duplicate Records: {duplicates}")
# Out:
# Duplicate Records: 0

# %%
# Drop transaction identifier columns
df.drop(columns=["nameOrig", "nameDest"], inplace=True)

print("Irrelevant columns removed successfully.")
# Out:
# Irrelevant columns removed successfully.

# %%
# Dataset shape after cleaning
print("Dataset Shape After Cleaning:", df.shape)
# Out:
# Dataset Shape After Cleaning: (6362620, 9)

# %%
# Create a final data quality report
cleaning_report = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Unique Values": df.nunique()
})

cleaning_report
# Out:
#                Data Type  Missing Values  Unique Values
# step               int64               0            743
# type              object               0              5
# amount           float64               0        5316900
# oldbalanceOrg    float64               0        1845844
# newbalanceOrig   float64               0        2682586
# oldbalanceDest   float64               0        3614697
# newbalanceDest   float64               0        3555499
# isFraud            int64               0              2
# isFlaggedFraud     int64               0              2

# %%
# Create a copy of the dataset to avoid modifying the original data
df_encoded = df.copy()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Identify categorical columns
categorical_columns = df_encoded.select_dtypes(include=['object']).columns

# Display categorical columns
print("Categorical Columns:")
print(categorical_columns)

# Apply LabelEncoder to categorical columns
for column in categorical_columns:
    df_encoded[column] = label_encoder.fit_transform(df_encoded[column])

# Display the first five rows after encoding
df_encoded.head()
# Out:
# Categorical Columns:
# Index(['type'], dtype='object')
#    step  type   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     3  9839.64      170136.00       160296.36            0.00
# 1     1     3  1864.28       21249.00        19384.72            0.00
# 2     1     4   181.00         181.00            0.00            0.00
# 3     1     1   181.00         181.00            0.00        21182.00
# 4     1     3 11668.14       41554.00        29885.86            0.00
#
#    newbalanceDest  isFraud  isFlaggedFraud
# 0            0.00        0               0
# 1            0.00        0               0
# 2            0.00        1               0
# 3            0.00        1               0
# 4            0.00        0               0

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ---
#
# # 📖 Overview
#
# Exploratory Data Analysis (EDA) is the process of examining and visualizing a dataset to better understand its characteristics before building machine learning models.
#
# EDA helps uncover hidden patterns, detect anomalies, identify relationships between variables, and generate insights that can improve feature engineering and model performance.
#
# For fraud detection, EDA is particularly important because fraudulent transactions are rare and often exhibit distinct behavioral patterns compared to legitimate transactions.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Understand the distribution of legitimate and fraudulent transactions.
# - Analyze different transaction types.
# - Examine transaction amounts.
# - Explore account balances before and after transactions.
# - Detect outliers.
# - Study feature relationships using correlation analysis.
# - Generate visual insights to guide feature engineering.

# %%
# Display dataset dimensions
print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")

# Fraud distribution
df['isFraud'].value_counts()
# Out:
# Rows    : 6362620
# Columns : 9
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
## Visualize Fraud Distribution
plt.figure(figsize=(6,5))

sns.countplot( x='isFraud', data=df, palette='Set2')

plt.title("Distribution of Fraudulent Transactions")
plt.xlabel("Fraud Status")
plt.ylabel("Count")

plt.xticks( [0,1],['Legitimate','Fraud'])

plt.show()

# %%
## Transaction Type Distribution
plt.figure(figsize=(8,5))

sns.countplot( x='type', data=df, palette='viridis')

plt.title("Transaction Type Distribution")
plt.xlabel("Transaction Type")
plt.ylabel("Count")

plt.xticks(rotation=30)

plt.show()

# %%
## Percentage of Transaction Types
transaction_percentage = ( df['type'].value_counts(normalize=True)*100).round(2)

transaction_percentage
# Out:
# type
# CASH_OUT   35.17
# PAYMENT    33.81
# CASH_IN    21.99
# TRANSFER    8.38
# DEBIT       0.65
# Name: proportion, dtype: float64

# %%
## Fraud by Transaction Type
plt.figure(figsize=(8,5))

sns.countplot( x='type', hue='isFraud', data=df, palette='Set1')

plt.title("Fraud Distribution Across Transaction Types")
plt.xlabel("Transaction Type")
plt.ylabel("Count")

plt.legend(["Legitimate","Fraud"])

plt.xticks(rotation=30)

plt.show()

# %%
## Transaction Amount Distribution
plt.figure(figsize=(10,6))

sns.histplot(df['amount'], bins=50,kde=True)

plt.title("Distribution of Transaction Amount")

plt.xlabel("Transaction Amount")

plt.ylabel("Frequency")

plt.show()

# %%
## Boxplot of Transaction Amount
plt.figure(figsize=(10,5))

sns.boxplot( x=df['amount'])

plt.title("Transaction Amount Boxplot")

plt.show()

# %%
# Correlation Heatmap
# Before plotting the heatmap, we need only numeric columns.

plt.figure(figsize=(12,8))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()

# %%
# Distribution of Numerical Features
numerical_columns = df.select_dtypes(include=['number']).columns

df[numerical_columns].hist(
    figsize=(18,12),
    bins=30)

plt.tight_layout()

plt.show()

# %% [markdown]
# # 🛠 Feature Engineering
#
# ---
#
# # 📖 Overview
#
# Feature engineering is the process of creating new variables from existing features to improve the predictive performance of machine learning models.
#
# In fraud detection, engineered features can reveal hidden transaction patterns that are difficult to detect using the original variables alone.
#
# Rather than relying solely on the raw dataset, we derive additional features that capture changes in account balances, transaction proportions, and unusually large transactions.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Create balance difference features.
# - Calculate balance error features.
# - Create amount-to-balance ratio features.
# - Identify unusually large transactions.
# - Validate the newly engineered features.

# %%
# Sender Balance Change
# Difference between sender's balance before and after the transaction
df["sender_balance_change"] = (df["oldbalanceOrg"] - df["newbalanceOrig"])

# Receiver Balance Change
# Difference between receiver's balance after and before the transaction
df["receiver_balance_change"] = (
    df["newbalanceDest"] - df["oldbalanceDest"])

# Balance Error (Sender)
# Difference between expected and actual sender balance
df["sender_balance_error"] = (
    df["oldbalanceOrg"] - df["amount"] - df["newbalanceOrig"])

# Balance Error (Receiver)
# Difference between expected and actual receiver balance
df["receiver_balance_error"] = (
    df["oldbalanceDest"] + df["amount"] - df["newbalanceDest"])

# %%
## Amount-to-Balance Ratio: To avoid division by zero, replace zero balances with NaN during the calculation.

df["amount_balance_ratio"] = (
    df["amount"] /
    df["oldbalanceOrg"].replace(0, np.nan))

df["amount_balance_ratio"] = df["amount_balance_ratio"].fillna(0)


# Large Transaction Indicator :Transactions above the 95th percentile are flagged as large transactions.

threshold = df["amount"].quantile(0.95)

df["large_transaction"] = (df["amount"] > threshold).astype(int)

# Verify the New Features
new_features = [
    "sender_balance_change",
    "receiver_balance_change",
    "sender_balance_error",
    "receiver_balance_error",
    "amount_balance_ratio",
    "large_transaction"]

df[new_features].head()
print("Dataset Shape:", df.shape)
df.columns.tolist()
# Out:
# Dataset Shape: (6362620, 15)
# ['step',
#  'type',
#  'amount',
#  'oldbalanceOrg',
#  'newbalanceOrig',
#  'oldbalanceDest',
#  'newbalanceDest',
#  'isFraud',
#  'isFlaggedFraud',
#  'sender_balance_change',
#  'receiver_balance_change',
#  'sender_balance_error',
#  'receiver_balance_error',
#  'amount_balance_ratio',
#  'large_transaction']

# %% [markdown]
# # ⚙️ Data Preprocessing
#
# ---
#
# # 📖 Overview
#
# Data preprocessing is the process of transforming raw data into a suitable format for machine learning algorithms.
#
# Most machine learning models cannot work directly with categorical variables and may perform better when numerical features are properly scaled.
#
# In this stage, we will prepare the dataset for model training by encoding categorical features and separating the input variables from the target variable.
#
# ---
#
# # 🎯 Objectives
#
# The objectives of this stage are to:
#
# - Encode categorical variables.
# - Separate features and target.
# - Verify the processed dataset.
# - Prepare the data for train-test splitting.

# %%
# Check Data Types: Display the data types of all columns
df.dtypes
# Out:
# step                         int64
# type                        object
# amount                     float64
# oldbalanceOrg              float64
# newbalanceOrig             float64
# oldbalanceDest             float64
# newbalanceDest             float64
# isFraud                      int64
# isFlaggedFraud               int64
# sender_balance_change      float64
# receiver_balance_change    float64
# sender_balance_error       float64
# receiver_balance_error     float64
# amount_balance_ratio       float64
# large_transaction            int64
# dtype: object

# %%
# Encode the Transaction Type: Since type is the only remaining categorical feature, we'll encode it using LabelEncoder.

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode the transaction type column
df["type"] = label_encoder.fit_transform(df["type"])

# Display the mapping
mapping = dict(zip(label_encoder.classes_,
                   label_encoder.transform(label_encoder.classes_)))

mapping
# Out:
# {'CASH_IN': np.int64(0),
#  'CASH_OUT': np.int64(1),
#  'DEBIT': np.int64(2),
#  'PAYMENT': np.int64(3),
#  'TRANSFER': np.int64(4)}

# %%
# Verify Encoding
df.head()

# Define Features and Target

X = df.drop("isFraud", axis=1)  # Independent variables
y = df["isFraud"]   # Target variable


X.head()   # Check Feature Matrix
y.head()   # Check Target Variable


# Display Dataset Shapes
print("Feature Matrix Shape :", X.shape)
print("Target Vector Shape  :", y.shape)


# Verify Target Distribution
y.value_counts()


# Check Feature Names
X.columns.tolist()


# Preview the Final Dataset
processed_df = pd.concat([X, y], axis=1)

processed_df.head()
# Out:
# Feature Matrix Shape : (6362620, 14)
# Target Vector Shape  : (6362620,)
#    step  type   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     3  9839.64      170136.00       160296.36            0.00
# 1     1     3  1864.28       21249.00        19384.72            0.00
# 2     1     4   181.00         181.00            0.00            0.00
# 3     1     1   181.00         181.00            0.00        21182.00
# 4     1     3 11668.14       41554.00        29885.86            0.00
#
#    newbalanceDest  isFlaggedFraud  sender_balance_change  \
# 0            0.00               0                9839.64
# 1            0.00               0                1864.28
# 2            0.00               0                 181.00
# 3            0.00               0                 181.00
# 4            0.00               0               11668.14
#
#    receiver_balance_change  sender_balance_error  receiver_balance_error  \
# ...

# %% [markdown]
# # ✂️ Train-Test Data Split
#
# ---
#
# # 📖 Overview
#
# Before training a machine learning model, the dataset must be divided into two subsets:
#
# - **Training Set** – Used to train the machine learning model.
# - **Testing Set** – Used to evaluate how well the trained model performs on unseen data.
#
# Separating the dataset helps prevent overfitting and provides a realistic assessment of the model's predictive ability.
#
# ---
#
# # 🎯 Objectives
#
# In this stage, we will:
#
# - Split the dataset into training and testing sets.
# - Use an 80:20 ratio.
# - Preserve the class distribution using stratified sampling.
# - Verify the shapes of the resulting datasets.

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

print("Dataset split completed successfully!")

# Check the Shapes
print(f"X_train Shape : {X_train.shape}")
print(f"X_test Shape  : {X_test.shape}")
print(f"y_train Shape : {y_train.shape}")
print(f"y_test Shape  : {y_test.shape}")

# Verify Fraud Distribution
y_train.value_counts()  # Training Set

y_test.value_counts()  # Testing Set
# Out:
# Dataset split completed successfully!
# X_train Shape : (5090096, 14)
# X_test Shape  : (1272524, 14)
# y_train Shape : (5090096,)
# y_test Shape  : (1272524,)
# isFraud
# 0    1270881
# 1       1643
# Name: count, dtype: int64

# %%
# Visualize the Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.countplot(x=y_train, ax=axes[0], palette="Set2")
axes[0].set_title("Training Set Distribution")
axes[0].set_xlabel("Fraud Status")
axes[0].set_ylabel("Count")
axes[0].set_xticklabels(["Legitimate", "Fraud"])

sns.countplot(x=y_test, ax=axes[1], palette="Set2")
axes[1].set_title("Testing Set Distribution")
axes[1].set_xlabel("Fraud Status")
axes[1].set_ylabel("Count")
axes[1].set_xticklabels(["Legitimate", "Fraud"])

plt.tight_layout()
plt.show()

# %% [markdown]
# # ⚖️ Feature Scaling
#
# ---
#
# # 📖 Overview
#
# Feature scaling is the process of transforming numerical features so that they share a similar scale.
#
# In the PaySim dataset, variables such as transaction amount and account balances have very different ranges. These differences can negatively affect certain machine learning algorithms.
#
# To address this, we standardize the features using **StandardScaler**, which transforms each feature to have:
#
# - A mean of approximately **0**
# - A standard deviation of approximately **1**
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Initialize the StandardScaler.
# - Fit the scaler using only the training dataset.
# - Transform both the training and testing datasets.
# - Verify that scaling was successful.
#
# ---
#
# # 📌 Why Feature Scaling?
#
# Feature scaling helps to:
#
# - Improve model convergence.
# - Prevent features with large values from dominating others.
# - Improve the performance of distance-based algorithms.
# - Prepare the data for SMOTE.

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and Transform the Training & Testing Data
X_train_scaled = scaler.fit_transform(X_train)  # Fit on training data and transform
X_test_scaled = scaler.transform(X_test)   # Transform testing data


# Verify the Shapes
print("Scaled Training Shape :", X_train_scaled.shape)
print("Scaled Testing Shape  :", X_test_scaled.shape)

# Convert Back to DataFrames : Keeping column names makes later analysis and debugging easier.

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)

X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)


# Preview the Scaled Training Data
X_train_scaled.head()

# Check Summary Statistics
X_train_scaled.describe().T

# Verify Column Names
X_train_scaled.columns.tolist()
# Out:
# Scaled Training Shape : (5090096, 14)
# Scaled Testing Shape  : (1272524, 14)
# ['step',
#  'type',
#  'amount',
#  'oldbalanceOrg',
#  'newbalanceOrig',
#  'oldbalanceDest',
#  'newbalanceDest',
#  'isFlaggedFraud',
#  'sender_balance_change',
#  'receiver_balance_change',
#  'sender_balance_error',
#  'receiver_balance_error',
#  'amount_balance_ratio',
#  'large_transaction']

# %% [markdown]
# # ⚖️ Handling Class Imbalance (SMOTE)
#
# ---
#
# # 📖 Overview
#
# In real-world fraud detection datasets, fraudulent transactions occur much less frequently than legitimate transactions. This creates a **class imbalance problem**, where machine learning models may become biased toward the majority class.
#
# The PaySim dataset is highly imbalanced, with legitimate transactions vastly outnumbering fraudulent ones. If left unaddressed, a model could achieve high accuracy simply by predicting every transaction as legitimate while failing to detect actual fraud.
#
# To overcome this challenge, we use **SMOTE (Synthetic Minority Over-sampling Technique)**.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Examine the class distribution before SMOTE.
# - Apply SMOTE to the training dataset only.
# - Generate synthetic fraud samples.
# - Verify the new class distribution.
# - Visualize the class balance before and after SMOTE.
#
# ---
#
# # 📌 Why SMOTE?
#
# SMOTE helps to:
#
# - Balance the dataset.
# - Improve fraud detection.
# - Reduce model bias toward the majority class.
# - Increase Recall and F1-score.
# - Improve the model's ability to identify rare fraud cases.

# %%
# Display class distribution before SMOTE
print("Class Distribution Before SMOTE:")
print(y_train.value_counts())


# Visualize Class Distribution Before SMOTE
plt.figure(figsize=(6,5))
sns.countplot(x=y_train,palette="Set2")
plt.title("Class Distribution Before SMOTE")
plt.xlabel("Fraud Status")
plt.ylabel("Number of Transactions")
plt.xticks([0,1], ["Legitimate","Fraud"])
plt.show()

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE: Apply SMOTE only on the training data
X_train_smote, y_train_smote = smote.fit_resample( X_train_scaled,y_train)

# Verify the New Dataset Shapes
print("Original Training Shape :", X_train_scaled.shape)
print("Balanced Training Shape:", X_train_smote.shape)


# Check Class Distribution After SMOTE
print("Class Distribution After SMOTE:")
print(y_train_smote.value_counts())


# Visualize Class Distribution After SMOTE
plt.figure(figsize=(6,5))
sns.countplot( x=y_train_smote, palette="viridis")
plt.title("Class Distribution After SMOTE")
plt.xlabel("Fraud Status")
plt.ylabel("Number of Transactions")
plt.xticks([0,1], ["Legitimate","Fraud"])
plt.show()


# Compare Before and After SMOTE
fig, axes = plt.subplots(1, 2, figsize=(12,5))
sns.countplot(x=y_train,ax=axes[0], palette="Set2")
axes[0].set_title("Before SMOTE")
axes[0].set_xticklabels(["Legitimate","Fraud"])
sns.countplot(x=y_train_smote, ax=axes[1],palette="viridis")
axes[1].set_title("After SMOTE")
axes[1].set_xticklabels(["Legitimate","Fraud"])
plt.tight_layout()
plt.show()

# Convert the balanced training features back to a DataFrame
X_train_smote = pd.DataFrame(X_train_smote, columns=X_train.columns)

# Convert the balanced target to a Series
y_train_smote = pd.Series(y_train_smote,name="isFraud")

# Preview the Balanced Dataset
X_train_smote.head()
y_train_smote.head()
# Out:
# Class Distribution Before SMOTE:
# isFraud
# 0    5083526
# 1       6570
# Name: count, dtype: int64
# Original Training Shape : (5090096, 14)
# Balanced Training Shape: (10167052, 14)
# Class Distribution After SMOTE:
# isFraud
# 0    5083526
# 1    5083526
# Name: count, dtype: int64
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: isFraud, dtype: int64

# %% [markdown]
# # 🤖 Machine Learning Model Training
#
# ---
#
# # 📖 Overview
#
# Machine learning model training is the process of teaching algorithms to recognize patterns in historical transaction data so they can accurately classify future transactions as either **legitimate** or **fraudulent**.
#
# In this project, we will train multiple supervised classification algorithms and compare their performance to identify the most effective model for fraud detection.
#
# Training multiple models allows us to evaluate different learning approaches and select the one that provides the best balance between accuracy and fraud detection capability.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Train multiple machine learning classification models.
# - Fit each model using the balanced training dataset.
# - Generate predictions on the testing dataset.
# - Evaluate model performance using multiple metrics.
# - Store the evaluation results for comparison.
#
# ---
#
# # 🤖 Machine Learning Algorithms
#
# The following algorithms will be trained:
#
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - Gradient Boosting
# - Extra Trees
# - XGBoost
# - LightGBM
#
# ---
#
# # 📌 Why Train Multiple Models?
#
# Different algorithms learn differently.
#
# Comparing multiple models helps us:
#
# - Identify the best-performing algorithm.
# - Improve fraud detection.
# - Reduce false positives.
# - Increase Recall and ROC-AUC.
# - Select the most suitable model for deployment.

# %%
# iMORT lIBRRIES.
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

models = { "Extra Trees": ExtraTreesClassifier(n_jobs=-1, random_state=42, n_estimators=50),
    "Logistic Regression": LogisticRegression(random_state=42, max_iter=1000, n_jobs=-1),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_jobs=-1, max_depth=12, n_estimators=50),
    "Gradient Boosting": HistGradientBoostingClassifier(random_state=42, max_depth=12),
    "XGBoost": XGBClassifier(
        random_state=42,
        eval_metric="logloss",
        use_label_encoder=False,
        tree_method="hist",
        device="cuda"), "LightGBM": LGBMClassifier(
        random_state=42, 
        device="cpu")}

# %%
# Create a Results List
results = []


# Train and Evaluate All Models
for model_name, model in models.items():
    print("=" * 60)
    print(f"Training {model_name}...")
    print("=" * 60)

    # Train model
    model.fit(X_train_smote, y_train_smote)

    # Prediction
    y_pred = model.predict(X_test_scaled)

    # Probability prediction
    y_prob = model.predict_proba(X_test_scaled)[:, 1]

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)

    precision = precision_score(y_test, y_pred)

    recall = recall_score(y_test, y_pred)

    f1 = f1_score(y_test, y_pred)

    roc_auc = roc_auc_score(y_test, y_prob)

    # Store results
    results.append({"Model": model_name,"Accuracy": accuracy,"Precision": precision,"Recall": recall,"F1 Score": f1,"ROC-AUC": roc_auc})
    print("Training Completed.\n")
# Out:
# ...
# Training Extra Trees...
# ...
# Training Completed.
#
# ...
# Training Logistic Regression...
# ...
# Training Completed.
#
# ...
# Training Decision Tree...
# ...
# Training Completed.
#
# ...
# Training Random Forest...
# ...
# Training Completed.
#
# ...
# Training Gradient Boosting...
# ...
# Training Completed.
#
# ...
# Training XGBoost...
# ...
# Training Completed.
#
# ...
# Training LightGBM...
# ...
# [LightGBM] [Info] Number of positive: 5083526, number of negative: 5083526
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.454161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2596
# [LightGBM] [Info] Number of data points in the train set: 10167052, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training Completed.

# %%
# Create Results DataFrame
results_df = pd.DataFrame(results)
results_df

# Sort Results
results_df = results_df.sort_values( by="ROC-AUC",ascending=False)
results_df.reset_index(drop=True, inplace=True)
results_df

# Round Values
results_df.iloc[:,1:] = results_df.iloc[:,1:].round(4)
results_df

# Highlight the Best Scores
results_df.style.highlight_max(color="lightgreen")


#Visualize Model Performance
plt.figure(figsize=(12,6))
sns.barplot(data=results_df,x="ROC-AUC",y="Model",palette="viridis")
plt.title("Machine Learning Model Comparison (ROC-AUC)")
plt.xlabel("ROC-AUC Score")
plt.ylabel("Model")
plt.show()


# Compare Accuracy
plt.figure(figsize=(12,6))
sns.barplot(data=results_df,x="Accuracy",y="Model",palette="Set2")
plt.title("Model Accuracy Comparison")
plt.show()


# Display the Final Ranking
results_df
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score  ROC-AUC
# 0             LightGBM      1.00       0.93    1.00      0.96     1.00
# 1        Random Forest      1.00       0.97    1.00      0.98     1.00
# 2    Gradient Boosting      1.00       0.95    1.00      0.97     1.00
# 3              XGBoost      1.00       0.96    1.00      0.98     1.00
# 4          Extra Trees      1.00       0.96    0.99      0.98     1.00
# 5        Decision Tree      1.00       0.97    1.00      0.98     1.00
# 6  Logistic Regression      0.97       0.04    0.91      0.07     0.99

# %% [markdown]
# # 📈 Model Evaluation
#
# ---
#
# # 📖 Overview
#
# Model evaluation is the process of measuring how well a trained machine learning model performs on unseen data.
#
# Since fraud detection is a binary classification problem with highly imbalanced classes, relying solely on accuracy can be misleading.
#
# Instead, we evaluate each model using several complementary metrics to obtain a comprehensive understanding of its performance.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Evaluate each trained model.
# - Generate confusion matrices.
# - Display classification reports.
# - Plot ROC curves.
# - Plot Precision-Recall curves.
# - Compare model performance.
#
# ---
#
# # 📌 Evaluation Metrics
#
# ### Accuracy
#
# Measures the proportion of correctly classified transactions.
#
# ---
#
# ### Precision
#
# Measures how many transactions predicted as fraud are actually fraudulent.
#
# ---
#
# ### Recall
#
# Measures how many actual fraudulent transactions are correctly detected.
#
# > **Recall is the most important metric in fraud detection because missing a fraudulent transaction can result in financial loss.**
#
# ---
#
# ### F1-Score
#
# The harmonic mean of Precision and Recall.
#
# ---
#
# ### ROC-AUC
#
# Measures the model's ability to distinguish between fraudulent and legitimate transactions.

# %%
## Import Additional Metrics
from sklearn.metrics import (ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay)

## Create Evaluation Function
def evaluate_model(model, model_name):
    """
    Evaluate a trained machine learning model.
    """

    # Predictions
    y_pred = model.predict(X_test_scaled)
    y_prob = model.predict_proba(X_test_scaled)[:, 1]

    print("="*70)
    print(f"{model_name}")
    print("="*70)

    # Metrics
    print(f"Accuracy : {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred):.4f}")
    print(f"Recall   : {recall_score(y_test, y_pred):.4f}")
    print(f"F1 Score : {f1_score(y_test, y_pred):.4f}")
    print(f"ROC AUC  : {roc_auc_score(y_test, y_prob):.4f}")

    print("\nClassification Report\n")
    print(classification_report(y_test, y_pred))

    # Confusion Matrix
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap="Blues")
    plt.title(f"{model_name} - Confusion Matrix")
    plt.show()

    # ROC Curve
    RocCurveDisplay.from_predictions(y_test, y_prob)
    plt.title(f"{model_name} - ROC Curve")
    plt.show()

    # Precision-Recall Curve
    PrecisionRecallDisplay.from_predictions(y_test, y_prob)
    plt.title(f"{model_name} - Precision-Recall Curve")

    plt.show()

# %%
## Evaluate Every Model
for model_name, model in models.items():
    evaluate_model(model, model_name)

## Display Summary Table
results_df

## Sort by Recall: Since fraud detection prioritizes finding fraudulent transactions, let's rank the models by Recall.

results_df.sort_values(by="Recall", ascending=False)

## Sort by ROC-AUC
results_df.sort_values(by="ROC-AUC", ascending=False)

## Sort by F1-Score
results_df.sort_values(by="F1 Score", ascending=False)
# Out:
# ...
# Extra Trees
# ...
# Accuracy : 0.9999
# Precision: 0.9605
# Recall   : 0.9915
# F1 Score : 0.9757
# ROC AUC  : 0.9994
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1270881
#            1       0.96      0.99      0.98      1643
#
#     accuracy                           1.00   1272524
#    macro avg       0.98      1.00      0.99   1272524
# weighted avg       1.00      1.00      1.00   1272524
# ...
# Logistic Regression
# ...
# Accuracy : 0.9701
# Precision: 0.0378
# Recall   : 0.9063
# F1 Score : 0.0726
# ROC AUC  : 0.9860
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98   1270881
#            1       0.04      0.91      0.07      1643
#
#     accuracy                           0.97   1272524
#    macro avg       0.52      0.94      0.53   1272524
# weighted avg       1.00      0.97      0.98   1272524
# ...
# Decision Tree
# ...

# %% [markdown]
# # 🎯 Hyperparameter Tuning
#
# ---
#
# # 📖 Overview
#
# Hyperparameter tuning is the process of finding the optimal combination of model parameters that produces the best predictive performance.
#
# Unlike model parameters, which are learned automatically during training, hyperparameters are configured before the training process begins.
#
# Selecting appropriate hyperparameters can significantly improve a model's ability to detect fraudulent transactions while reducing overfitting.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Select the best-performing models from the initial evaluation.
# - Define suitable hyperparameter search spaces.
# - Perform hyperparameter tuning using **RandomizedSearchCV**.
# - Identify the optimal hyperparameter combination.
# - Retrain the model using the best parameters.
# - Compare the tuned model with the original model.
#
# ---
#
# # 📌 Why RandomizedSearchCV?
#
# For large datasets like PaySim, **RandomizedSearchCV** is preferred over **GridSearchCV** because it:
#
# - Requires less computational time.
# - Explores a wide range of parameter combinations.
# - Produces competitive results.
# - Scales well to large datasets.

# %%
# 1. Downsample base training data to 10% to fit into your RAM comfortably
X_train_small = pd.DataFrame(X_train).sample(frac=0.10, random_state=42)
y_train_small = pd.Series(y_train).loc[X_train_small.index]

# 2. Re-run SMOTE step ONLY on this smaller 10% sample
# (Replace 'smote' with whatever your actual SMOTE object variable is named)
X_train_smote, y_train_smote = smote.fit_resample(X_train_small, y_train_small)

# 3. Force your data to lower precision to save an extra 50% memory
X_train_smote = X_train_smote.astype('float32')

# %%
## Convert the entire DataFrame to float32
df = df.astype('float32')

# Import Hyperparameter Tuning Tools
from sklearn.model_selection import RandomizedSearchCV


## Define the Random Forest Hyperparameter Grid
rf_params = {"n_estimators": [100, 200, 300], "max_depth": [10, 20, 30, None], "min_samples_split": [2, 5, 10], "min_samples_leaf": [1, 2, 4], "max_features": ["sqrt", "log2"]}

## Initialize the Random Forest Model
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
from joblib import parallel_backend
## Configure RandomizedSearchCV:  We use Recall as the optimization metric because detecting fraudulent transactions is our primary objective.
rf_random = RandomizedSearchCV( estimator=rf, param_distributions=rf_params, n_iter=5, scoring="recall", cv=3, verbose=3, random_state=42, n_jobs=1)


## Train the Search using the threading backend to save RAM
with parallel_backend('threading'):
    rf_random.fit(X_train_smote, y_train_smote)

## Display the Best Parameters
print("Best Parameters:")
rf_random.best_params_


## Display the Best Recall Score
print("Best Cross-Validation Recall:")
print(rf_random.best_score_)


## Retrieve the Best Model
best_rf = rf_random.best_estimator_


## Make Predictions
y_pred_rf = best_rf.predict(X_test_scaled)
y_prob_rf = best_rf.predict_proba(X_test_scaled)[:, 1]


## Evaluate the Tuned Model
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))
print("ROC-AUC  :", roc_auc_score(y_test, y_prob_rf))


##Classification Report
print(classification_report(y_test, y_pred_rf))


## Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf, cmap="Greens")
plt.title("Tuned Random Forest - Confusion Matrix")
plt.show()


## ROC Curve
RocCurveDisplay.from_predictions(y_test, y_prob_rf)
plt.title("Tuned Random Forest - ROC Curve")
plt.show()


## Precision-Recall Curve
PrecisionRecallDisplay.from_predictions(y_test, y_prob_rf)
plt.title("Tuned Random Forest - Precision-Recall Curve")
plt.show()
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=1.000 total time=  38.4s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=1.000 total time=  37.0s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=1.000 total time=  35.4s
# [CV 1/3] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=1.000 total time=  36.6s
# [CV 2/3] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=1.000 total time=  35.6s
# [CV 3/3] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=1.000 total time=  35.6s
# ...

# %% [markdown]
# # 🏆 Best Model Selection
#
# ---
#
# # 📖 Overview
#
# Selecting the best machine learning model requires comparing multiple algorithms based on appropriate evaluation metrics.
#
# In fraud detection systems, the cost of missing fraudulent transactions is usually higher than the cost of investigating legitimate transactions incorrectly classified as fraud.
#
# Therefore, the selected model should achieve a strong balance between detecting fraud cases and minimizing false alarms.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Combine results from all trained models.
# - Include the tuned Random Forest model.
# - Compare performance metrics.
# - Rank models based on fraud detection capability.
# - Select the final deployment model.
#
# ---
#
# # 📌 Model Selection Criteria
#
# The final model will be selected based on:
#
# | Metric | Importance |
# |---|---|
# | Recall | Highest priority (detect fraud cases) |
# | ROC-AUC | Ability to separate fraud/non-fraud |
# | F1 Score | Balance between Precision and Recall |
# | Precision | Reduce false alerts |
# | Accuracy | Overall correctness |

# %%
# Calculate tuned Random Forest metrics
tuned_rf_result = {"Model": "Tuned Random Forest", "Accuracy": accuracy_score(y_test, y_pred_rf), "Precision": precision_score(y_test, y_pred_rf),"Recall": recall_score(y_test, y_pred_rf),

    "F1 Score": f1_score(y_test, y_pred_rf), "ROC-AUC": roc_auc_score(y_test, y_prob_rf)}
tuned_rf_result


# Convert tuned result into DataFrame
tuned_results_df = pd.DataFrame([tuned_rf_result])


# Combine with previous results
final_results = pd.concat([results_df, tuned_results_df], ignore_index=True)
final_results
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score  ROC-AUC
# 0             LightGBM      1.00       0.93    1.00      0.96     1.00
# 1        Random Forest      1.00       0.97    1.00      0.98     1.00
# 2    Gradient Boosting      1.00       0.95    1.00      0.97     1.00
# 3              XGBoost      1.00       0.96    1.00      0.98     1.00
# 4          Extra Trees      1.00       0.96    0.99      0.98     1.00
# 5        Decision Tree      1.00       0.97    1.00      0.98     1.00
# 6  Logistic Regression      0.97       0.04    0.91      0.07     0.99
# 7  Tuned Random Forest      1.00       0.00    0.00      0.00     0.70

# %%
# Rank models based on fraud detection ability
final_results.sort_values(by="Recall", ascending=False)

final_results.sort_values(by="ROC-AUC", ascending=False)

# Final ranking
model_ranking = final_results.sort_values(by=[ "Recall", "ROC-AUC", "F1 Score"], ascending=False)
model_ranking.reset_index(drop=True, inplace=True)
model_ranking


## Visualize Final Model Comparison
plt.figure(figsize=(12,6))
sns.barplot(data=model_ranking, x="Recall", y="Model", palette="viridis")
plt.title("Model Comparison Based on Recall")
plt.xlabel("Recall Score")
plt.ylabel("Machine Learning Model")
plt.show()

# %%
# Select the top-ranked model name
best_model_name = model_ranking.iloc[0]["Model"]
best_model_name

## Assign Final Model
if best_model_name == "Tuned Random Forest":
    final_model = best_rf
else:
    final_model = models[best_model_name]
print(f"Selected Model: {best_model_name}")
# Out:
# Selected Model: Random Forest

# %% [markdown]
# # 🔍 Fraud Prediction System
#
# ---
#
# # 📖 Overview
#
# A machine learning model becomes more useful when it can make predictions on new, unseen data.
#
# In this section, we create a fraud prediction system that allows users to enter transaction details and receive an instant prediction.
#
# The system uses the selected best-performing model from the previous stage.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Create a prediction function.
# - Prepare new transaction data.
# - Apply the same preprocessing steps used during training.
# - Generate fraud predictions.
# - Display prediction probabilities.
# - Classify transaction risk level.

# %%
## Create Prediction Function
def predict_fraud(transaction):

    """
    Predict whether a transaction is fraudulent.

    Input:
    transaction - pandas DataFrame containing one transaction

    Output:
    prediction and fraud probability
    """

    # Apply same scaling used during training
    transaction_scaled = scaler.transform(transaction)

    # Generate prediction
    prediction = final_model.predict(transaction_scaled)


    # Generate probability
    probability = final_model.predict_proba(transaction_scaled)[:,1]

    if prediction[0] == 1:
        result = "Fraudulent Transaction"
    else:
        result = "Legitimate Transaction"
    return {"Prediction": result, "Fraud Probability": round(probability[0], 4)}

##Create Sample Transaction 
# Select one legitimate transaction example
sample_transaction = X_test.iloc[[0]]
sample_transaction
# Out:
#          step  type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 4051353   300     4 890577.21         218.00            0.00            0.00
#
#          newbalanceDest  isFlaggedFraud  sender_balance_change  \
# 4051353       890577.21               0                 218.00
#
#          receiver_balance_change  sender_balance_error  \
# 4051353                     0.00            -890359.21
#
#          receiver_balance_error  amount_balance_ratio  large_transaction
# 4051353                    0.00               4085.22                  1

# %%
## Test Fraud Prediction
prediction_result = predict_fraud(sample_transaction)
prediction_result
# Out:
# {'Prediction': 'Legitimate Transaction',
#  'Fraud Probability': np.float64(0.0003)}

# %%
## Create a Fraud Risk Category
def fraud_risk(probability):
    if probability < 0.30:
        return "Low Risk"
    elif probability < 0.70:
        return "Medium Risk"
    else:
        return "High Risk"

## Apply Risk Classification
result = predict_fraud(sample_transaction)
risk = fraud_risk(result["Fraud Probability"])
result["Risk Level"] = risk
result
# Out:
# {'Prediction': 'Legitimate Transaction',
#  'Fraud Probability': np.float64(0.0003),
#  'Risk Level': 'Low Risk'}

# %%
# Test With a Fraud Transaction
# Select an actual fraudulent transaction from test data
fraud_index = y_test[y_test == 1].index[0]
fraud_transaction = X_test.loc[[fraud_index]]
fraud_transaction
# Out:
#          step  type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 6202693   583     1 759701.03      759701.03            0.00      1076095.67
#
#          newbalanceDest  isFlaggedFraud  sender_balance_change  \
# 6202693      1835796.71               0              759701.03
#
#          receiver_balance_change  sender_balance_error  \
# 6202693                     0.00                  0.00
#
#          receiver_balance_error  amount_balance_ratio  large_transaction
# 6202693                   -0.01                  1.00                  1

# %%
# Predict fraud transaction
predict_fraud(fraud_transaction)
# Out:
# {'Prediction': 'Fraudulent Transaction', 'Fraud Probability': np.float64(1.0)}

# %%
## Create User Input Template
new_transaction = pd.DataFrame({"step": [1], "type": [4], "amount": [50000], "oldbalanceOrg": [60000], "newbalanceOrig": [10000], "oldbalanceDest": [0], "newbalanceDest": [50000],

    "sender_balance_change": [50000], "receiver_balance_change": [50000],"sender_balance_error": [0], "receiver_balance_error": [0], "amount_balance_ratio": [0.83], "large_transaction": [1]})
new_transaction
# Out:
#    step  type  amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     4   50000          60000           10000               0
#
#    newbalanceDest  sender_balance_change  receiver_balance_change  \
# 0           50000                  50000                    50000
#
#    sender_balance_error  receiver_balance_error  amount_balance_ratio  \
# 0                     0                       0                  0.83
#
#    large_transaction
# 0                  1

# %%
# Add the missing feature required by the scaler
new_transaction['isFlaggedFraud'] = [0]

# Automatically match the exact columns and order from training
new_transaction = new_transaction[scaler.feature_names_in_]

# 3. Make Prediction
predict_fraud(new_transaction)
# Out:
# {'Prediction': 'Legitimate Transaction',
#  'Fraud Probability': np.float64(0.1399)}

# %% [markdown]
# # 📖 Overview
#
# Deployment preparation is the process of packaging a trained machine learning model so it can be used in real-world applications.
#
# A deployed fraud detection system requires not only the trained model but also all preprocessing components used during training.
#
# In this section, we will save the complete machine learning pipeline components and prepare the project structure for deployment.
#
# ---
#
# # 🎯 Objectives
#
# In this section, we will:
#
# - Save the final trained model.
# - Save the feature scaler.
# - Save the label encoder.
# - Save the feature list.
# - Verify saved files.
# - Prepare deployment requirements.

# %%
## Import Required Library
import joblib
import os


# Create folder for saved files
os.makedirs("fraud_detection_model",exist_ok=True)

print("Folder created successfully!")


# Save trained model
joblib.dump(final_model,"fraud_detection_model/final_fraud_model.pkl")
print("Model saved successfully!")


# Save scaler
joblib.dump(scaler, "fraud_detection_model/scaler.pkl")
print("Scaler saved successfully!")


## Save Label Encoder
joblib.dump(label_encoder,"fraud_detection_model/label_encoder.pkl")
print("Encoder saved successfully!")


# Save feature names
feature_names = X.columns.tolist()
joblib.dump(feature_names,"fraud_detection_model/features.pkl")
print("Feature list saved successfully!")


## Verify Saved Files
os.listdir("fraud_detection_model")
# Out:
# Folder created successfully!
# Model saved successfully!
# Scaler saved successfully!
# Encoder saved successfully!
# Feature list saved successfully!
# ['features.pkl', 'final_fraud_model.pkl', 'label_encoder.pkl', 'scaler.pkl']

# %%
# Load saved model
loaded_model = joblib.load("fraud_detection_model/final_fraud_model.pkl")
print("Model loaded successfully!")

# Make prediction using loaded model
loaded_prediction = loaded_model.predict(X_test_scaled.iloc[[0]])
loaded_prediction
# Out:
# Model loaded successfully!
# array([0])

# %% [markdown]
# # 🌐 Streamlit Fraud Detection Web Application
#
# ---
#
# ## Overview
#
# Streamlit allows us to transform a trained machine learning model into an interactive web application.
#
# The application provides a user-friendly interface where users can enter transaction details and receive instant fraud predictions.
#
# ---
#
# ## Application Features
#
# The fraud detection application will:
#
# - Load the trained machine learning model.
# - Load preprocessing objects.
# - Accept transaction details from users.
# - Apply the same preprocessing pipeline.
# - Predict fraud probability.
# - Display transaction risk level.

# %%
from IPython.display import IFrame

# Display the running Streamlit dashboard inside your notebook
IFrame(src="http://localhost:8507", width="100%", height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:8507"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
